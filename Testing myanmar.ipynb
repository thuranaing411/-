# %% [markdown]
# <a href="https://colab.research.google.com/github/thuranaing411/-/blob/master/Testing%20myanmar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install plotly.plotly
import numpy as np 
import pandas as pd

from subprocess import check_output
#print(check_output(["ls", "../input"]).decode("utf8"))

import os
import matplotlib.pyplot as plt
#import plotly.plotly as py
import plotly.graph_objs as go
import plotly.tools as tls
import seaborn as sns
from pylab import figure, axes, pie, title, show
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', 100)

Religion = pd.read_csv('regional.csv')
religionAll = Religion[['region','year','christianity_all','judaism_all','islam_all','buddhism_all','zoroastrianism_all','hinduism_all','sikhism_all','confucianism_all','noreligion_all']].copy() 
religionByAfrica = religionAll[religionAll['region']=="Africa"]
Religion.head()
# Out:
# ERROR: Could not find a version that satisfies the requirement plotly.plotly (from versions: none)
# ERROR: No matching distribution found for plotly.plotly
#    year     region  christianity_protestant  christianity_romancatholic  \
# 0  1945     Africa                  2074180                      672337
# 1  1945       Asia                  2407144                     2222908
# 2  1945     Europe                 83145512                   216041422
# 3  1945    Mideast                    87174                      635929
# 4  1945  West. Hem                 73173575                   171759439
#
#    christianity_easternorthodox  christianity_anglican  christianity_other  \
# 0                       7251492                 419457             4170594
# 1                        181928                3142204             1964907
# 2                      86503645               29855595             5361826
# 3                       3180260                      0              108332
# ...

# %%
religionByAfrica.reset_index()
colors = ['c', 'g', 'r', 'b', 'm','y', 'k', 'w', '#FF0033', '#FF8833','#FF0088']
ax = religionByAfrica[['christianity_all','judaism_all','islam_all','buddhism_all','hinduism_all','sikhism_all','confucianism_all','noreligion_all']].plot(kind='bar', title ="African Population", color=colors)
ax.set_xlabel("Year",fontsize=12)
ax.set_ylabel("Population", fontsize=12)
ax.set_xticklabels(religionByAfrica['year'])
# Out:
# [Text(0, 0, '1945'),
#  Text(0, 0, '1950'),
#  Text(0, 0, '1955'),
#  Text(0, 0, '1960'),
#  Text(0, 0, '1965'),
#  Text(0, 0, '1970'),
#  Text(0, 0, '1975'),
#  Text(0, 0, '1980'),
#  Text(0, 0, '1985'),
#  Text(0, 0, '1990'),
#  Text(0, 0, '1995'),
#  Text(0, 0, '2000'),
#  Text(0, 0, '2005'),
#  Text(0, 0, '2010')]

# %%
religionByAsia = religionAll[religionAll['region']=="Asia"]

religionByAsia.reset_index()

ax = religionByAsia[['christianity_all','judaism_all','islam_all','buddhism_all','hinduism_all','sikhism_all','confucianism_all','noreligion_all']].plot(kind='bar', title ="Asian Population", color=colors)
ax.set_xlabel("Year",fontsize=12)
ax.set_ylabel("Population", fontsize=12)
ax.set_xticklabels(religionByAfrica['year'])
# Out:
# [Text(0, 0, '1945'),
#  Text(0, 0, '1950'),
#  Text(0, 0, '1955'),
#  Text(0, 0, '1960'),
#  Text(0, 0, '1965'),
#  Text(0, 0, '1970'),
#  Text(0, 0, '1975'),
#  Text(0, 0, '1980'),
#  Text(0, 0, '1985'),
#  Text(0, 0, '1990'),
#  Text(0, 0, '1995'),
#  Text(0, 0, '2000'),
#  Text(0, 0, '2005'),
#  Text(0, 0, '2010')]

# %%
religionByMidEast = religionAll[religionAll['region']=="Mideast"]

religionByMidEast.reset_index()

ax = religionByMidEast[['christianity_all','judaism_all','islam_all','buddhism_all','hinduism_all','sikhism_all','confucianism_all','noreligion_all']].plot(kind='bar', title ="Middle-East Population", color=colors)
ax.set_xlabel("Year",fontsize=12)
ax.set_ylabel("Population", fontsize=12)
ax.set_xticklabels(religionByMidEast['year'])
plt.show()

# %%
Religion = pd.read_csv('national.csv')
religionAll = Religion[['state','year','code','christianity_all',
                        'buddhism_all']].copy()

# %%
religionByCountry =religionAll
religionByCountry.reset_index()
# Out:
#       index                     state  year code  christianity_all  \
# 0         0  United States of America  1945  USA         110265118
# 1         1  United States of America  1950  USA         122994019
# 2         2  United States of America  1955  USA         134001770
# 3         3  United States of America  1960  USA         150234347
# 4         4  United States of America  1965  USA         167515758
# ...     ...                       ...   ...  ...               ...
# 1990   1990                     Samoa  1990  WSM            159500
# 1991   1991                     Samoa  1995  WSM            161677
# 1992   1992                     Samoa  2000  WSM            174600
# 1993   1993                     Samoa  2005  WSM            177510
# 1994   1994                     Samoa  2010  WSM            180140
#
#       buddhism_all
# 0          1601218
# 1                0
# 2            90173
# 3          2012131
# 4          1080892
# ...            ...
# ...

# %%
ax = religionByCountry['buddhism_all'].plot(kind='bar', title ="Population", color=colors)
#ax = religionByCountry['christianity_all'].plot(kind='bar', title ="Population", color=colors)
ax.set_xlabel("year",fontsize=12)
ax.set_ylabel("population", fontsize=12)
ax.set_xticklabels(religionByCountry['year'])
# Out:
# [Text(0, 0, '1945'),
#  Text(0, 0, '1950'),
#  Text(0, 0, '1955'),
#  Text(0, 0, '1960'),
#  Text(0, 0, '1965'),
#  Text(0, 0, '1970'),
#  Text(0, 0, '1975'),
#  Text(0, 0, '1980'),
#  Text(0, 0, '1985'),
#  Text(0, 0, '1990'),
#  Text(0, 0, '1995'),
#  Text(0, 0, '2000'),
#  Text(0, 0, '2005'),
#  Text(0, 0, '2010'),
#  Text(0, 0, '1945'),
#  Text(0, 0, '1950'),
#  Text(0, 0, '1955'),
#  Text(0, 0, '1960'),
#  Text(0, 0, '1965'),
#  Text(0, 0, '1970'),
#  Text(0, 0, '1975'),
#  Text(0, 0, '1980'),
#  Text(0, 0, '1985'),
#  Text(0, 0, '1990'),
#  Text(0, 0, '1995'),
#  Text(0, 0, '2000'),
#  Text(0, 0, '2005'),
#  Text(0, 0, '2010'),
#  Text(0, 0, '1975'),
#  Text(0, 0, '1980'),
#  Text(0, 0, '1985'),
#  Text(0, 0, '1990'),
#  Text(0, 0, '1995'),
#  Text(0, 0, '2000'),
#  Text(0, 0, '2005'),
#  Text(0, 0, '2010'),
#  Text(0, 0, '1945'),
#  Text(0, 0, '1950'),
#  Text(0, 0, '1955'),
#  Text(0, 0, '1960'),
#  Text(0, 0, '1965'),
#  Text(0, 0, '1970'),
#  Text(0, 0, '1975'),
# ...

# %%
religionByCountry_Myanmar = religionAll[religionAll['state']=='Myanmar']

religionByCountry_Myanmar.reset_index()
# Out:
#     index    state  year code  christianity_all  buddhism_all
# 0    1749  Myanmar  1950  MYA            727351      14031137
# 1    1750  Myanmar  1955  MYA           1027748      14866360
# 2    1751  Myanmar  1960  MYA           1349526      16766250
# 3    1752  Myanmar  1965  MYA           1336791      18305680
# 4    1753  Myanmar  1970  MYA           1393749      20862636
# 5    1754  Myanmar  1975  MYA           1933395      22929200
# 6    1755  Myanmar  1980  MYA           2473040      25227750
# 7    1756  Myanmar  1985  MYA           2237250      29946775
# 8    1757  Myanmar  1990  MYA           2488600      32049350
# 9    1758  Myanmar  1995  MYA           3157420      33355000
# 10   1759  Myanmar  2000  MYA           3210000      34909000
# 11   1760  Myanmar  2005  MYA           4429920      41406500
# 12   1761  Myanmar  2010  MYA           4565000      43983776

# %%
ax = religionByCountry_Myanmar[['christianity_all','judaism_all','islam_all','buddhism_all','hinduism_all','sikhism_all','confucianism_all','noreligion_all']].plot(kind='bar', title ="Myanmar Population", color=colors)
ax.set_xlabel("Year",fontsize=12)
ax.set_ylabel("Population", fontsize=12)
ax.set_xticklabels(religionByCountry_Myanmar['year'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-7ac3afe21575> in <module>()
# ----> 1 ax = religionByCountry_Myanmar[['christianity_all','judaism_all','islam_all','buddhism_all','hinduism_all','sikhism_all','confucianism_all','noreligion_all']].plot(kind='bar', title ="Myanmar Population", color=colors)
#       2 ax.set_xlabel("Year",fontsize=12)
#       3 ax.set_ylabel("Population", fontsize=12)
#       4 ax.set_xticklabels(religionByCountry_Myanmar['year'])
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2910             if is_iterator(key):
#    2911                 key = list(key)
# -> 2912             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2913
#    2914         # take() does not accept boolean indexers
#
# ...

# %%
religionByCountry_China = religionAll[religionAll['state']=='China']
religionByCountry_China.reset_index()

ax = religionByCountry_China[['christianity_all','judaism_all','islam_all','buddhism_all','hinduism_all','sikhism_all','confucianism_all','noreligion_all']].plot(kind='bar', title ="China Population", color=colors)
ax.set_xlabel("Year",fontsize=12)
ax.set_ylabel("Population", fontsize=12)
ax.set_xticklabels(religionByCountry_China['year'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-f8deb2185d9f> in <module>()
#       2 religionByCountry_China.reset_index()
#       3
# ----> 4 ax = religionByCountry_China[['christianity_all','judaism_all','islam_all','buddhism_all','hinduism_all','sikhism_all','confucianism_all','noreligion_all']].plot(kind='bar', title ="China Population", color=colors)
#       5 ax.set_xlabel("Year",fontsize=12)
#       6 ax.set_ylabel("Population", fontsize=12)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2910             if is_iterator(key):
#    2911                 key = list(key)
# -> 2912             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2913
#    2914         # take() does not accept boolean indexers
#
# ...

# %%
colour = ['r','b']
religionByCountry_USA = religionAll[religionAll['state']=='United States of America']
religionByCountry_USA.reset_index()

ax = religionByCountry_USA[['christianity_all','buddhism_all']].plot(kind='bar', title ="USA Population", color=['b','r'])
ax.set_xlabel("Year",fontsize=12)
ax.set_ylabel("Population", fontsize=12)
ax.set_xticklabels(religionByCountry_USA['year'])
# Out:
# [Text(0, 0, '1945'),
#  Text(0, 0, '1950'),
#  Text(0, 0, '1955'),
#  Text(0, 0, '1960'),
#  Text(0, 0, '1965'),
#  Text(0, 0, '1970'),
#  Text(0, 0, '1975'),
#  Text(0, 0, '1980'),
#  Text(0, 0, '1985'),
#  Text(0, 0, '1990'),
#  Text(0, 0, '1995'),
#  Text(0, 0, '2000'),
#  Text(0, 0, '2005'),
#  Text(0, 0, '2010')]

# %%
religionByCountry_USA = religionAll[religionAll['state']=='United States of America']
religionByCountry_USA.reset_index()

ax = religionByCountry_USA['christianity_all'].plot(kind='bar', title ="USA Population", color='r')
ax.set_xlabel("Year",fontsize=12)
ax.set_ylabel("Population", fontsize=12)
ax.set_xticklabels(religionByCountry_USA['year'])
# Out:
# [Text(0, 0, '1945'),
#  Text(0, 0, '1950'),
#  Text(0, 0, '1955'),
#  Text(0, 0, '1960'),
#  Text(0, 0, '1965'),
#  Text(0, 0, '1970'),
#  Text(0, 0, '1975'),
#  Text(0, 0, '1980'),
#  Text(0, 0, '1985'),
#  Text(0, 0, '1990'),
#  Text(0, 0, '1995'),
#  Text(0, 0, '2000'),
#  Text(0, 0, '2005'),
#  Text(0, 0, '2010')]

# %%
religionByCountry_Myanmar = religionAll[religionAll['state']=='Myanmar']
religionByCountry_Myanmar.reset_index()

ax = religionByCountry_Myanmar[['christianity_all','buddhism_all']].plot(kind='bar', title ="Myanmar Population", color=['b','r'])
ax.set_xlabel("Year",fontsize=12)
ax.set_ylabel("Population", fontsize=12)
ax.set_xticklabels(religionByCountry_Myanmar['year'])
# Out:
# [Text(0, 0, '1950'),
#  Text(0, 0, '1955'),
#  Text(0, 0, '1960'),
#  Text(0, 0, '1965'),
#  Text(0, 0, '1970'),
#  Text(0, 0, '1975'),
#  Text(0, 0, '1980'),
#  Text(0, 0, '1985'),
#  Text(0, 0, '1990'),
#  Text(0, 0, '1995'),
#  Text(0, 0, '2000'),
#  Text(0, 0, '2005'),
#  Text(0, 0, '2010')]
